# %%
def mnerreadfile(filename):
    '''
    read file
    return format :
    [ ['EU', 'B-ORG'], ['rejects', 'O'], ['German', 'B-MISC'], ['call', 'O'], ['to', 'O'], ['boycott', 'O'], ['British', 'B-MISC'], ['lamb', 'O'], ['.', 'O'] ]
    '''
    f = open(filename)
    data = []
    imgs = []
    auxlabels = []
    sentence = []
    label = []
    auxlabel = []
    imgid = ''
    for line in f:
        if line.startswith('IMGID:'):
            imgid = line.strip().split('IMGID:')[1]+'.jpg'
            continue
        if line[0] == "\n":
            if len(sentence) > 0:
                data.append((sentence, label))
                imgs.append(imgid)
                auxlabels.append(auxlabel)
                sentence = []
                label = []
                imgid = ''
                auxlabel = []
            continue
        splits = line.split('\t')
        sentence.append(splits[0])
        cur_label = splits[-1][:-1]
        if cur_label == 'B-OTHER':
            cur_label = 'B-MISC'
        elif cur_label == 'I-OTHER':
            cur_label = 'I-MISC'
        label.append(cur_label)
        auxlabel.append(cur_label[0])

    if len(sentence) > 0:
        data.append((sentence, label))
        imgs.append(imgid)
        auxlabels.append(auxlabel)
        sentence = []
        label = []
        auxlabel = []

    print("The number of samples: " + str(len(data)))
    print("The number of images: " + str(len(imgs)))
    return data, imgs, auxlabels

# %%
mnerreadfile('/home/ubuntu/multimodal-fusion/datasets/IJCAI2019_data/twitter2015/train.txt')
# Out:
# The number of samples: 1
# The number of images: 1
# ([(['RT @ ltsChuckBass : $T$ is everything # MCM\n',
#     'Chuck Bass\n',
#     '1\n',
#     '1860693.jpg\n',
#     'RT @ ltsChuckBass : Chuck Bass is everything $T$ \n',
#     '# MCM\n',
#     '0\n',
#     '1860693.jpg\n',
#     '$T$ September 7 - - - - Shut Down New York City\n',
#     'Millions For Trayvon\n',
#     '0\n',
#     '195984.jpg\n',
#     'Millions For Trayvon September 7 - - - - Shut Down $T$ \n',
#     'New York City\n',
#     '-1\n',
#     '195984.jpg\n',
#     'Me as $T$ .\n',
#     'John Lennon\n',
#     '1\n',
#     '871618.jpg\n',
#     'Former $T$ boss Rod Petricevic will be released from jail next month .\n',
#     'Bridgecorp\n',
#     '0\n',
#     '280704.jpg\n',
#     'Former Bridgecorp boss $T$ will be released from jail next month .\n',
#     'Rod Petricevic\n',
#     '-1\n',
#     '280704.jpg\n',
#     'Tried $T$ for an out of game Halo 5 experience and holograms are totally awesome # E3\n',
#     'HoloLens\n',
#     '1\n',
#     '638395.jpg\n',
#     'Tried HoloLens for an out of game Halo 5 experience and holograms are totally awesome $T$ \n',
#     '# E3\n',
#     '1\n',
#     '638395.jpg\n',
#     'RT @ BBC Travel : Chasing light and shadows in beautiful $T$ : # architecture\n',
#     '# Iran\n',
#     '1\n',
#     '138186.jpg\n',
#     'RT @ MySportsLegion : $T$ is already wearing a Johnny Football Browns jersey . ( via @ WFNYScott )\n',
#     'LeBron James\n',
#     '0\n',
#     '512435.jpg\n',
#     'RT @ MySportsLegion : LeBron James is already wearing a $T$ Football Browns jersey . ( via @ WFNYScott )\n',
#     'Johnny\n',
#     '0\n',
#     '512435.jpg\n',
#     'RT @ MySportsLegion : LeBron James is already wearing a Johnny $T$ jersey . ( via @ WFNYScott )\n',
#     'Football Browns\n',
#     '0\n',
#     '512435.jpg\n',
#     'RT @ arasmusKTVU : # BaytoBreakers race delayed because of unstable arch at $T$ ( per Mayors office ) # KTVU\n',
#     'Hayes st hill\n',
#     '-1\n',
#     '722168.jpg\n',
#     'RT @ arasmusKTVU : # BaytoBreakers race delayed because of unstable arch at Hayes st hill ( per Mayors office ) $T$ \n',
#     '# KTVU\n',
#     '0\n',
#     '722168.jpg\n',
#     '$T$ gov candidate Kirk Dillard greets supporters as the race tightens on primary election night\n',
#     'GOP\n',
#     '1\n',
#     '74090.jpg\n',
#     'GOP gov candidate $T$ greets supporters as the race tightens on primary election night\n',
#     'Kirk Dillard\n',
#     '1\n',
#     '74090.jpg\n',
#     'RT @ BI Defense : $T$ scrambles Typhoon jets to see off Russian bombers\n',
#     'Britain\n',
#     '0\n',
#     '73066.jpg\n',
#     '$T$ tells # Congobrazza to do more to attract foreign companies in agriculture\n',
#     'UNCTAD\n',
#     '0\n',
#     '623109.jpg\n',
#     'Hanging out with $T$ # Blackhawks # WinterClassic\n',
#     'Corey\n',
#     '1\n',
#     '71953.jpg\n',
#     'Hanging out with Corey $T$ # WinterClassic\n',
#     '# Blackhawks\n',
#     '1\n',
#     '71953.jpg\n',
#     'RT @ ESPN FirstTake : I think he should STAY in $T$ . - @ stephenasmith # RevisFuture\n',
#     'New England\n',
#     '0\n',
#     '1748621.jpg\n',
#     '$T$ holds its own mini - parade around 70th anniversary of WWII victory : https : t . co JNz6Ocp595\n',
#     'Taiwan\n',
#     '0\n',
#     '559998.jpg\n',
#     'Taiwan holds its own mini - parade around 70th anniversary of $T$ victory : https : t . co JNz6Ocp595\n',
#     'WWII\n',
#     '1\n',
#     '559998.jpg\n',
#     '. @ TheSwonBrothers @ SwonBrothers Performing July 24th at the $T$ \n',
#     'Fayette County Fair\n',
#     '0\n',
#     '578058.jpg\n',
#     'RT @ nytimes : A French take on tagine , from $T$ \n',
#     'Daniel Boulud\n',
#     '0\n',
#     '117833.jpg\n',
#     'RT @ thehill : Poll : $T$ amp Trump lead 2016 GOP field\n',
#     'Bush\n',
#     '0\n',
#     '116990.jpg\n',
#     'RT @ thehill : Poll : Bush amp $T$ lead 2016 GOP field\n',
#     'Trump\n',
#     '0\n',
#     '116990.jpg\n',
#     'RT @ thehill : Poll : Bush amp Trump lead 2016 $T$ field\n',
#     'GOP\n',
#     '0\n',
#     '116990.jpg\n',
#     'RT @ business : $T$ is now almost twice as valuable as the next biggest company on Earth\n',
#     'Apple\n',
#     '1\n',
#     '38154.jpg\n',
#     'RT @ barrabest : A great photo of $T$ . Taken @ DeeGregg .\n',
#     '# Belfast City Hall\n',
#     '1\n',
#     '488240.jpg\n',
#     "$T$ celebrates his goal , but the good times didn ' t last . # Blackhawks fall :\n",
#     'Brent Seabrook\n',
#     '1\n',
#     '70943.jpg\n',
#     "Brent Seabrook celebrates his goal , but the good times didn ' t last . $T$ fall :\n",
#     '# Blackhawks\n',
#     '-1\n',
#     '70943.jpg\n',
#     'This is a fantastic idea - a purifying wave pool for surfers built into the $T$ :\n',
#     'Rotterdam canals\n',
#     '0\n',
#     '569602.jpg\n',
#     "RT @ Cosmopolitan : It ' s OK if these sexy shirtless photos of TFIOS ' $T$ makes you . . . feel things\n",
#     'Ansel Elgort\n',
#     '0\n',
#     '73141.jpg\n',
#     'RT @ BarackObama : # ClimateChangeIsReal . So are the actions $T$ is taking to tackle it .\n',
#     'President Obama\n',
#     '1\n',
#     '1490725.jpg\n',
#     'RT @ Swiftwriting : $T$ looking absolutely flawless at the BBC Teen Awards .\n',
#     'Taylor\n',
#     '1\n',
#     '37498.jpg\n',
#     'RT @ Swiftwriting : Taylor looking absolutely flawless at the $T$ .\n',
#     'BBC Teen Awards\n',
#     '0\n',
#     '37498.jpg\n',
#     '@ Louis Garneau Join I Am Able : a handicap cycling team that originated in $T$ .\n',
#     'Rwanda\n',
#     '0\n',
#     '446463.jpg\n',
#     'RT @ NATO : $T$ appoints @ jensstoltenberg as # NATO SG as of October 1st 2014\n',
#     'North Atlantic Council\n',
#     '0\n',
#     '68397.jpg\n',
#     'RT @ NATO : North Atlantic Council appoints @ jensstoltenberg as $T$ SG as of October 1st 2014\n',
#     '# NATO\n',
#     '0\n',
#     '68397.jpg\n',
#     'RT @ htmgarcia : Drones are banned in $T$ - I expected this could be a gossip # Japan\n',
#     '# Hiroshima Peace Memorial Park\n',
#     '-1\n',
#     '617578.jpg\n',
#     'RT @ htmgarcia : Drones are banned in # Hiroshima Peace Memorial Park - I expected this could be a gossip $T$ \n',
#     '# Japan\n',
#     '0\n',
#     '617578.jpg\n',
#     'Results from @ IronTrac for $T$ @ # Ironman # Raleigh 70 . 3 2014\n',
#     'Christine Allen\n',
#     '0\n',
#     '638357.jpg\n',
#     'Results from @ IronTrac for Christine Allen @ # Ironman $T$ 70 . 3 2014\n',
#     '# Raleigh\n',
#     '0\n',
#     '638357.jpg\n',
#     '# TBT 2 months ago today this pic was taken during # Sochi2014 final . What was @ SledSweeney13 saying to $T$ ?\n',
#     'Tyler Carron\n',
#     '0\n',
#     '701488.jpg\n',
#     'Check out the summer issue of @ familytraveller they give you the best tips for a family to discover $T$ in 48h !\n',
#     'Marrakech\n',
#     '1\n',
#     '1326656.jpg\n',
#     'RT @ HistoryPixs : $T$ when she was only 16 years old .\n',
#     'Angelina Jolie\n',
#     '0\n',
#     '1953977.jpg\n',
#     'RT @ WildWiseDevon : In the spring , at the end of the day , you should smell like dirt . $T$ \n',
#     'Margaret Atwood\n',
#     '0\n',
#     '521612.jpg\n',
#     'RT @ MrFox13 : $T$ need to go here with the boys\n',
#     'Defo\n',
#     '0\n',
#     '1336838.jpg\n',
#     'Swan upping : first stop $T$ , Tower Bridge ( Tower and Olympic rings in the background )\n',
#     'Hermitage Warf\n',
#     '0\n',
#     '1109405.jpg\n',
#     'Swan upping : first stop Hermitage Warf , $T$ ( Tower and Olympic rings in the background )\n',
#     'Tower Bridge\n',
#     '0\n',
#     '1109405.jpg\n',
#     'Swan upping : first stop Hermitage Warf , Tower Bridge ( $T$ and Olympic rings in the background )\n',
#     'Tower\n',
#     '0\n',
#     '1109405.jpg\n',
#     'Swan upping : first stop Hermitage Warf , Tower Bridge ( Tower and $T$ rings in the background )\n',
#     'Olympic\n',
#     '0\n',
#     '1109405.jpg\n',
#     'This passes for snow in $T$ # blackhawks # winterclassic\n',
#     'DC\n',
#     '0\n',
#     '72008.jpg\n',
#     'This passes for snow in DC $T$ # winterclassic\n',
#     '# blackhawks\n',
#     '0\n',
#     '72008.jpg\n',
#     'RT @ thinkprogress : $T$ and the invisible plight of black women in the justice system\n',
#     'Sandra Bland\n',
#     '0\n',
#     '570930.jpg\n',
#     'RT @ LadyGagaNowNet : $T$ getting a drink at the bar at The Oscars 2014 .\n',
#     'Lady Gaga\n',
#     '0\n',
#     '1472725.jpg\n',
#     'RT @ LadyGagaNowNet : Lady Gaga getting a drink at $T$ bar at The Oscars 2014 .\n',
#     'the\n',
#     '0\n',
#     '1472725.jpg\n',
#     'RT @ LadyGagaNowNet : Lady Gaga getting a drink at the bar at $T$ 2014 .\n',
#     'The Oscars\n',
#     '0\n',
#     '1472725.jpg\n',
#     '@ BetterCallSaul : Happy birthday , $T$ ! Happy birthday , master !\n',
#     'Vince Gilligan\n',
#     '1\n',
#     '34793.jpg\n',
#     '$T$ and SDU Campus Kolding have been awarded The International Architecture Award\n',
#     'Moesgaard Museum\n',
#     '1\n',
#     '1075863.jpg\n',
#     'Moesgaard Museum and $T$ have been awarded The International Architecture Award\n',
#     'SDU Campus Kolding\n',
#     '1\n',
#     '1075863.jpg\n',
#     'Moesgaard Museum and SDU Campus Kolding have been awarded $T$ \n',
#     'The International Architecture Award\n',
#     '0\n',
#     '1075863.jpg\n',
#     'RT @ AnimalsAsia : Special Report : Dog meat wars : 5 stories that shocked $T$ \n',
#     'Vietnam\n',
#     '0\n',
#     '1027114.jpg\n',
#     'RT @ Steve OS : $T$ Achievement Unlocked\n',
#     'DeAndre Jordan\n',
#     '1\n',
#     '21311.jpg\n',
#     'BREAKING NEWS : $T$ youngster Junior Malanda has died in a car accident , according to BILD .\n',
#     'Wolfsburg\n',
#     '0\n',
#     '669523.jpg\n',
#     'BREAKING NEWS : Wolfsburg youngster $T$ has died in a car accident , according to BILD .\n',
#     'Junior Malanda\n',
#     '-1\n',
#     '669523.jpg\n',
#     'BREAKING NEWS : Wolfsburg youngster Junior Malanda has died in a car accident , according to $T$ .\n',
#     'BILD\n',
#     '0\n',
#     '669523.jpg\n',
#     'RT @ zgarrison3 : @ ukghosthunting $T$ According to Herman Klein , it was taken in 1898 : )\n',
#     'The Elixir Of Youth\n',
#     '0\n',
#     '659252.jpg\n',
#     'RT @ zgarrison3 : @ ukghosthunting The Elixir Of Youth According to $T$ , it was taken in 1898 : )\n',
#     'Herman Klein\n',
#     '0\n',
#     '659252.jpg\n',
#     'One week to go until our visit to the Australian Embassy in $T$ for morning tea with the Ambassador .\n',
#     'Indonesia\n',
#     '0\n',
#     '130789.jpg\n',
#     'RT @ BobBuckhorn : $T$ opens new lacrosse stadium . Generous donation from Vince Namoli made it happen .\n',
#     'U of Tampa\n',
#     '1\n',
#     '70471.jpg\n',
#     'RT @ BobBuckhorn : U of Tampa opens new lacrosse stadium . Generous donation from $T$ made it happen .\n',
#     'Vince Namoli\n',
#     '1\n',
#     '70471.jpg\n',
#     '@ harunmaruf : Outside # BuloMarer , $T$ commander Gen . Dick Olum finds a souvenir after al # shabab were overwhelmed !\n',
#     'AMISOM\n',
#     '0\n',
#     '1009286.jpg\n',
#     '@ harunmaruf : Outside # BuloMarer , AMISOM commander $T$ . Dick Olum finds a souvenir after al # shabab were overwhelmed !\n',
#     'Gen\n',
#     '0\n',
#     '1009286.jpg\n',
#     '@ harunmaruf : Outside # BuloMarer , AMISOM commander Gen . $T$ finds a souvenir after al # shabab were overwhelmed !\n',
#     'Dick Olum\n',
#     '0\n',
#     '1009286.jpg\n',
#     'RT @ buziosglobalusa : $T$ in # Tokyo Station # HappyHolidays\n',
#     '# Christmas\n',
#     '1\n',
#     '500370.jpg\n',
#     'RT @ buziosglobalusa : # Christmas in $T$ # HappyHolidays\n',
#     '# Tokyo Station\n',
#     '1\n',
#     '500370.jpg\n',
#     'So sorry to hear about $T$ and Kris Medlen needing # TommyJohn again . Great pitchers .\n',
#     'Jarrod Parker\n',
#     '-1\n',
#     '886689.jpg\n',
#     'So sorry to hear about Jarrod Parker and $T$ needing # TommyJohn again . Great pitchers .\n',
#     'Kris Medlen\n',
#     '-1\n',
#     '886689.jpg\n',
#     'RT @ InsideHoops : $T$ update :\n',
#     'DeAndre Jordan\n',
#     '0\n',
#     '480117.jpg\n',
#     'Honored to be here in $T$ @ jworldwatch IWitness Award given to Intel 4 commitment to only use conflict free minerals\n',
#     'LA\n',
#     '1\n',
#     '13680.jpg\n',
#     'Honored to be here in LA @ jworldwatch IWitness Award given to $T$ commitment to only use conflict free minerals\n',
#     'Intel 4\n',
#     '1\n',
#     '13680.jpg\n',
#     'Second awesome event of the day : Open Schools $T$ launch @ GroundTruthIn @ DGateway @ OpenGovHub\n',
#     'Kenya\n',
#     '1\n',
#     '1717237.jpg\n',
#     'RT @ favecrushes : $T$ before and after\n',
#     'Aaron Johnson\n',
#     '0\n',
#     '1787734.jpg\n',
#     'RT @ MarinaConcert : $T$ meeting diamonds after the show tonight ! ! !\n',
#     'Marina\n',
#     '1\n',
#     '65352.jpg\n',
#     '# Cancer patient $T$ and family pose with @ NdamukongSuh for the # GameOnCancer fundraising campaign .\n',
#     'Michael Gabriel\n',
#     '0\n',
#     '557517.jpg\n',
#     'RT @ THEMAZElSACODE : RT if $T$ is your favorite character in The Maze Runner trilogy !\n',
#     'Newt\n',
#     '1\n',
#     '515898.jpg\n',
#     'This is where $T$ Lincoln was not only born , but raised . Amy Schumer at Lincoln Center\n',
#     'Abe\n',
#     '0\n',
#     '2077969.jpg\n',
#     'This is where Abe $T$ was not only born , but raised . Amy Schumer at Lincoln Center\n',
#     'Lincoln\n',
#     '0\n',
#     '2077969.jpg\n',
#     'This is where Abe Lincoln was not only born , but raised . $T$ at Lincoln Center\n',
#     'Amy Schumer\n',
#     '0\n',
#     '2077969.jpg\n',
#     'This is where Abe Lincoln was not only born , but raised . Amy Schumer at $T$ \n',
#     'Lincoln Center\n',
#     '0\n',
#     '2077969.jpg\n',
#     'RT @ 1D Beards : Real life $T$ ? I think so . - Blaze\n',
#     'Peter Pan\n',
#     '0\n',
#     '1908966.jpg\n',
#     'RT @ chicagotribune : Update : $T$ says no planes in U . S . destined to cross Midwest can depart until at least 10 a . m . h\n',
#     'FAA\n',
#     '-1\n',
#     '73134.jpg\n',
#     'RT @ chicagotribune : Update : FAA says no planes in U . S . destined to cross $T$ can depart until at least 10 a . m . h\n',
#     'Midwest\n',
#     '0\n',
#     '73134.jpg\n',
#     'RT @ EarthBeauties : $T$ , California\n',
#     'San Francisco\n',
#     '0\n',
#     '525824.jpg\n',
#     'RT @ EarthBeauties : San Francisco , $T$ \n',
#     'California\n',
#     '0\n',
#     '525824.jpg\n',
#     'RT @ ABCFpll : RT if you would want $T$ to bring you pie ! # FatalFinale\n',
#     'Ezra\n',
#     '0\n',
#     '127300.jpg\n',
#     '10 Tips for Better Smartphone Photography from $T$ Founder Flo Meissner\n',
#     'EyeEm\n',
#     '0\n',
#     '116790.jpg\n',
#     '10 Tips for Better Smartphone Photography from EyeEm Founder $T$ \n',
#     'Flo Meissner\n',
#     '0\n',
#     '116790.jpg\n',
#     'RT @ lindsapple : In two years , $T$ has aged 10 years and also become the Hulk .\n',
#     'Bryce Harper\n',
#     '1\n',
#     '1831392.jpg\n',
#     'RT @ lindsapple : In two years , Bryce Harper has aged 10 years and also become the $T$ .\n',
#     'Hulk\n',
#     '0\n',
#     '1831392.jpg\n',
#     '. @ RoKhannaUSA visited $T$ today , what a great community in # Milpitas # CA17\n',
#     'Good Shepherd Community Church\n',
#     '1\n',
#     '703723.jpg\n',
#     '. @ RoKhannaUSA visited Good Shepherd Community Church today , what a great community in $T$ # CA17\n',
#     '# Milpitas\n',
#     '0\n',
#     '703723.jpg\n',
#     'RT @ Lokatza ZE : @ MikelAristi Seguran garaile . ZORIONAK MIKEL ! ! $T$ # TXIRRINDULARITZA\n',
#     '# BERGARA\n',
#     '0\n',
#     '641920.jpg\n',
#     'RT @ JasperBol : Exercising replenishment at sea approaches en route $T$ !\n',
#     'Scotland\n',
#     '1\n',
#     '73252.jpg\n',
#     'RT @ CIothesPorn : $T$ defender Julie Johnston is perfection\n',
#     'USA\n',
#     '0\n',
#     '1377967.jpg\n',
#     'RT @ CIothesPorn : USA defender $T$ is perfection\n',
#     'Julie Johnston\n',
#     '1\n',
#     '1377967.jpg\n',
#     'Hmm , my trip to # NewYork this Friday looks quite . . refreshing . Just like going back home to $T$ : ) # snow # travel\n',
#     '# finland\n',
#     '1\n',
#     '424585.jpg\n',
#     'RT @ cherylmcnamara : To change everything we need everyone . At Mayday studio in $T$ . Artists prep for # PeoplesMarch .\n',
#     'Brooklyn\n',
#     '0\n',
#     '70574.jpg\n',
#     '$T$ at # LiarTimesNow rubbishes everyone who produces a counter opinion ! Unhealthy debates and opinionated agenda !\n',
#     'Arnab\n',
#     '-1\n',
#     '818604.jpg\n',
#     'RT @ robindbrant : rifkind statement to the $T$ over cash for access claims from daily telegraph channel 4\n',
#     'BBC\n',
#     '0\n',
#     '1767744.jpg\n',
#     'NEW : Incredibly $T$ Born in the Streets , by David Zinn -\n',
#     'Quirky Chalk Art\n',
#     '1\n',
#     '1063211.jpg\n',
#     'NEW : Incredibly Quirky Chalk Art Born in the Streets , by $T$ -\n',
#     'David Zinn\n',
#     '0\n',
#     '1063211.jpg\n',
#     '$T$ thought we all need to have the courage to be wise , as though something is precluding us\n',
#     'Kant\n',
#     '0\n',
#     '1141954.jpg\n',
#     '$T$ in a mascot suit on Shark Tank\n',
#     'Bill Walton\n',
#     '0\n',
#     '1062932.jpg\n',
#     'Ahem @ inallthechaos haha : ) RT @ heyitskenn @ FootyHumour Where it all went wrong for $T$ \n',
#     'Spain\n',
#     '1\n',
#     '1005869.jpg\n',
#     'Children were part of history in $T$ , 1965 : # OccupySELMA\n',
#     '# Selma\n',
#     '0\n',
#     '1042378.jpg\n',
#     'Need a $T$ ? We can help\n',
#     '# DataLake Foundation\n',
#     '0\n',
#     '111515.jpg\n',
#     'RT @ FemalePains : $T$ still trying to find those 75 , 000 earrings that Kim lost in the ocean\n',
#     'Kris\n',
#     '0\n',
#     '807130.jpg\n',
#     'RT @ FemalePains : Kris still trying to find those 75 , 000 earrings that $T$ lost in the ocean\n',
#     'Kim\n',
#     '-1\n',
#     '807130.jpg\n',
#     'RT @ KardashianReact : $T$ loves his wife so he holds her hand . Kanye loves Kanye so he holds Kanye hand .\n',
#     'John\n',
#     '0\n',
#     '450320.jpg\n',
#     'RT @ KardashianReact : John loves his wife so he holds her hand . $T$ loves Kanye so he holds Kanye hand .\n',
#     'Kanye\n',
#     '0\n',
#     '450320.jpg\n',
#     'RT @ KardashianReact : John loves his wife so he holds her hand . Kanye loves $T$ so he holds Kanye hand .\n',
#     'Kanye\n',
#     '1\n',
#     '450320.jpg\n',
#     'RT @ KardashianReact : John loves his wife so he holds her hand . Kanye loves Kanye so he holds $T$ hand .\n',
#     'Kanye\n',
#     '1\n',
#     '450320.jpg\n',
#     'RT @ bloemhof54 : There are always flowers for those who want to see them . - $T$ \n',
#     'Henri Matisse\n',
#     '0\n',
#     '872892.jpg\n',
#     'RT @ shaunwalker7 : Lord , $T$ has an entire section of mad books about Ukraine\n',
#     'Dom Knigi\n',
#     '0\n',
#     '23390.jpg\n',
#     'RT @ shaunwalker7 : Lord , Dom Knigi has an entire section of mad books about $T$ \n',
#     'Ukraine\n',
#     '-1\n',
#     '23390.jpg\n',
#     'RT @ SoonerScoop : # Sooners latest commitment CB Parrish Cobb ( @ pcthedb4 ) of $T$ before his first scrimmage of the year .\n',
#     'Waco La Vega\n',
#     '0\n',
#     '74684.jpg\n',
#     'RT @ ksatnews : SAFD : People trapped in elevator at $T$ # KSATnews\n',
#     'Tower of the Americas\n',
#     '-1\n',
#     '20107.jpg\n',
#     'RT @ washingtonpost : Human safaris in the $T$ may put uncontacted tribes at risk\n',
#     'Amazon basin\n',
#     '0\n',
#     '7865.jpg\n',
#     "First day of school in $T$ and at Cameron Elementary . This kindergartener wasn ' t impressed by the mayoral visit\n",
#     'Chicago\n',
#     '0\n',
#     '70395.jpg\n',
#     "First day of school in Chicago and at $T$ . This kindergartener wasn ' t impressed by the mayoral visit\n",
#     'Cameron Elementary\n',
#     '-1\n',
#     '70395.jpg\n',
#     'Currency is participation and social engagement . RT @ LesaUkman IEG : $T$ speaking at # IEG2013 , @ Movember\n',
#     'Adam Garrone\n',
#     '0\n',
#     '116551.jpg\n',
#     'RT @ ThisIsRobThomas : A Message from $T$ https : t . co erjtQifL80\n',
#     'Mari\n',
#     '1\n',
#     '1765264.jpg\n',
#     'Join us today at 9am amp 11am as Pastor $T$ brings a powerful message on how God has created you to change the game !\n',
#     'Keith\n',
#     '1\n',
#     '92180.jpg\n',
#     'Resolved : $T$ are the best snack food on the market .\n',
#     'Takis Fuego\n',
#     '1\n',
#     '875874.jpg\n',
#     'RT @ Luke5SOS : $T$ and Luigi dominated the dance floor as per usual\n',
#     'Mario\n',
#     '1\n',
#     '254182.jpg\n',
#     'RT @ Luke5SOS : Mario and $T$ dominated the dance floor as per usual\n',
#     'Luigi\n',
#     '1\n',
#     '254182.jpg\n',
#     '$T$ officer injured after vehicle flips at Ashland Montrose . Intersection closed , avoid\n',
#     'CPD\n',
#     '-1\n',
#     '73093.jpg\n',
#     'RT @ ZaibatsuPlanet : Pink Morning by $T$ # photo\n',
#     'Zermie\n',
#     '0\n',
#     '480647.jpg\n',
#     'RT @ timring3TV : Meet $T$ high - level prospect Anthony Duclair tonight at 6 : 25 on @ 3TVSports\n',
#     'Coyotes\n',
#     '0\n',
#     '423017.jpg\n',
#     'RT @ timring3TV : Meet Coyotes high - level prospect $T$ tonight at 6 : 25 on @ 3TVSports\n',
#     'Anthony Duclair\n',
#     '0\n',
#     '423017.jpg\n',
#     'My view at breakfast today . $T$ .\n',
#     'Breckinridge\n',
#     '0\n',
#     '478533.jpg\n',
#     '$T$ expands Calibre 110 collection with new Calibre 111 RT @ elevenjames\n',
#     'Oris\n',
#     '0\n',
#     '116290.jpg\n',
#     'Oris expands $T$ collection with new Calibre 111 RT @ elevenjames\n',
#     'Calibre 110\n',
#     '0\n',
#     '116290.jpg\n',
#     'Oris expands Calibre 110 collection with new $T$ RT @ elevenjames\n',
#     'Calibre 111\n',
#     '0\n',
#     '116290.jpg\n',
#     'Contact $T$ to outlaw puppy mills in 2015 . @ ALDF has taken the lead please RT\n',
#     'Congress\n',
#     '0\n',
#     '128023.jpg\n',
#     '$T$ family says Keith left a good job w family business and was aware of dangers fighting ISIS # FOX25\n',
#     'Broomfield\n',
#     '0\n',
#     '41899.jpg\n',
#     'Broomfield family says $T$ left a good job w family business and was aware of dangers fighting ISIS # FOX25\n',
#     'Keith\n',
#     '1\n',
#     '41899.jpg\n',
#     'Broomfield family says Keith left a good job w family business and was aware of dangers fighting $T$ # FOX25\n',
#     'ISIS\n',
#     '-1\n',
#     '41899.jpg\n',
#     '$T$ \n',
#     'William Hague\n',
#     '1\n',
#     '550071.jpg\n',
#     'RT @ ermnarry : Retweet if they are your source of happiness # Vote1D $T$ \n',
#     '# KCA\n',
#     '0\n',
#     '926460.jpg\n',
#     'Free drinks ? Magic ! Register your $T$ amp start earning the way to Gold : # goforgold\n',
#     'Starbucks Card\n',
#     '1\n',
#     '506192.jpg\n',
#     'RT @ PaulHeggenWSMV : Tornado Warning for $T$ county . Rotation just south of Lebanon .\n',
#     'Wilson\n',
#     '-1\n',
#     '384951.jpg\n',
#     'RT @ PaulHeggenWSMV : Tornado Warning for Wilson county . Rotation just south of $T$ .\n',
#     'Lebanon\n',
#     '-1\n',
#     '384951.jpg\n',
#     'Visiting $T$ , The Philippines via @ michaelturtle # ttot # travel # volcano\n',
#     'Taal Volcano\n',
#     '0\n',
#     '812074.jpg\n',
#     'Visiting Taal Volcano , The $T$ via @ michaelturtle # ttot # travel # volcano\n',
#     'Philippines\n',
#     '0\n',
#     '812074.jpg\n',
#     'Ladies and gentlemen , I present $T$ -\n',
#     'Goldman Sachs\n',
#     '-1\n',
#     '822293.jpg\n',
#     'Single vehicle crash into light pole closes $T$ intersection .\n',
#     'Gilbert\n',
#     '-1\n',
#     '421295.jpg\n',
#     'RT @ Inspiredneuron : When I let go of what I have , I receive what I need - $T$ \n',
#     'Lao Tzu\n',
#     '0\n',
#     '240616.jpg\n',
#     'Thanks $T$ for # Hagerstown bike tour\n',
#     '# CVCC\n',
#     '1\n',
#     '481201.jpg\n',
#     'Thanks # CVCC for $T$ bike tour\n',
#     '# Hagerstown\n',
#     '1\n',
#     '481201.jpg\n',
#     'RT @ MuggleNet : Wishing $T$ a very Happy Birthday today ! # HappyBirthdayMaggieSmith\n',
#     'Dame Maggie Smith\n',
#     '1\n',
#     '146252.jpg\n',
#     'RT @ LDN : $T$ last night # CharlieHebdo\n',
#     'Paris\n',
#     '1\n',
#     '49622.jpg\n',
#     'RT @ TheBeautifulCar : $T$ \n',
#     'Galaxy Ferrari\n',
#     '1\n',
#     '14665.jpg\n',
#     'RT @ WillHillBet : The $T$ fans gave Xavi a nice send off . # 6raciesXavi # LaLiga\n',
#     'Barcelona\n',
#     '1\n',
#     '90078.jpg\n',
#     'RT @ WillHillBet : The Barcelona fans gave $T$ a nice send off . # 6raciesXavi # LaLiga\n',
#     'Xavi\n',
#     '1\n',
#     '90078.jpg\n',
#     'RT @ T twitt : $T$ amp Julie Christie\n',
#     'Raquel Welch\n',
#     '1\n',
#     '93184.jpg\n',
#     'RT @ T twitt : Raquel Welch amp $T$ \n',
#     'Julie Christie\n',
#     '1\n',
#     '93184.jpg\n',
#     '# One2watch $T$ already won 3 # Paralympic medals ! RT if you think he can add some more # Road2Sochi\n',
#     'Jakub Krako\n',
#     '1\n',
#     '699969.jpg\n',
#     '# One2watch Jakub Krako already won 3 $T$ medals ! RT if you think he can add some more # Road2Sochi\n',
#     '# Paralympic\n',
#     '0\n',
#     '699969.jpg\n',
#     '$T$ by Richard Wagner at the ancient Roman theatre of Athens\n',
#     'Flying Dutschman\n',
#     '0\n',
#     '29896.jpg\n',
#     'Flying Dutschman by $T$ at the ancient Roman theatre of Athens\n',
#     'Richard Wagner\n',
#     '0\n',
#     '29896.jpg\n',
#     'Flying Dutschman by Richard Wagner at the ancient $T$ theatre of Athens\n',
#     'Roman\n',
#     '0\n',
#     '29896.jpg\n',
#     'Flying Dutschman by Richard Wagner at the ancient Roman theatre of $T$ \n',
#     'Athens\n',
#     '0\n',
#     '29896.jpg\n',
#     'RT @ BostonDotCom : 40 years ago today , $T$ schools were ordered to desegregate\n',
#     'Boston\n',
#     '0\n',
#     '33908.jpg\n',
#     'Walking home from school over blood stains in $T$ , hours after a man died . # NextDayChi 10 :\n',
#     'Gresham\n',
#     '-1\n',
#     '71471.jpg\n',
#     'RT @ Rotorfocus : The $T$ is trying out the SABIR pylon on its C - 130Js turning it into a multi - mission platform .\n',
#     'Danish Air Force\n',
#     '0\n',
#     '72618.jpg\n',
#     'RT @ Rotorfocus : The Danish Air Force is trying out the SABIR pylon on its $T$ turning it into a multi - mission platform .\n',
#     'C - 130Js\n',
#     '0\n',
#     '72618.jpg\n',
#     '$T$ : this Wed nite 7 . 23 - spinning an all - James Brown set before this free film screening at St . Nicholas Park .\n',
#     'NYC\n',
#     '0\n',
#     '94015.jpg\n',
#     'RT @ Welcome us : . @ Chirlane McCray , wife of $T$ Mayor Bill De Blasio , has Bajan Ghanian ancestry ! # IHM2015\n',
#     'NYC\n',
#     '0\n',
#     '605818.jpg\n',
#     'RT @ Welcome us : . @ Chirlane McCray , wife of NYC $T$ , has Bajan Ghanian ancestry ! # IHM2015\n',
#     'Mayor Bill De Blasio\n',
#     '1\n',
#     '605818.jpg\n',
#     'RT @ Welcome us : . @ Chirlane McCray , wife of NYC Mayor Bill De Blasio , has $T$ Ghanian ancestry ! # IHM2015\n',
#     'Bajan\n',
#     '1\n',
#     '605818.jpg\n',
#     'RT @ Welcome us : . @ Chirlane McCray , wife of NYC Mayor Bill De Blasio , has Bajan $T$ ancestry ! # IHM2015\n',
#     'Ghanian\n',
#     '1\n',
#     '605818.jpg\n',
#     'Preparing the sand at $T$ for Memorial Day weekend . Chicago beaches open Saturday !\n',
#     'Hayes Beach\n',
#     '0\n',
#     '73853.jpg\n',
#     'Preparing the sand at Hayes Beach for $T$ weekend . Chicago beaches open Saturday !\n',
#     'Memorial Day\n',
#     '0\n',
#     '73853.jpg\n',
#     'Preparing the sand at Hayes Beach for Memorial Day weekend . $T$ beaches open Saturday !\n',
#     'Chicago\n',
#     '0\n',
#     '73853.jpg\n',
#     'RT @ ShitBsbPlyrsSay : The $T$ made the rookies go get Coffee\n',
#     'Cardinals\n',
#     '0\n',
#     '74167.jpg\n',
#     'RT @ AjaySharmaFCO : Delighted to be back in $T$ and that the Embassy has reopened . # UK # Iran\n',
#     'Tehran\n',
#     '1\n',
#     '1779633.jpg\n',
#     'RT @ AjaySharmaFCO : Delighted to be back in Tehran and that the Embassy has reopened . $T$ # Iran\n',
#     '# UK\n',
#     '0\n',
#     '1779633.jpg\n',
#     'RT @ AjaySharmaFCO : Delighted to be back in Tehran and that the Embassy has reopened . # UK $T$ \n',
#     '# Iran\n',
#     '0\n',
#     '1779633.jpg\n',
#     'RT @ StephanieArts : My drawing of @ LaurenSocha as $T$ . Hope you like it ! # Misfits # misstheshow\n',
#     'Kelly Bailey\n',
#     '0\n',
#     '1084327.jpg\n',
#     'RT @ StephanieArts : My drawing of @ LaurenSocha as Kelly Bailey . Hope you like it ! $T$ # misstheshow\n',
#     '# Misfits\n',
#     '0\n',
#     '1084327.jpg\n',
#     'RT @ 1DInfectionMNL : $T$ from January 2014 to December 2014 # 14MomentsOfZayn\n',
#     'Zayn\n',
#     '0\n',
#     '1719707.jpg\n',
#     'RT @ CHANBAEKUNION : VOTE FOR BAEKHYUN AS $T$ PRESIDENT . HAHAHAHHAA : D ( cr . garcon )\n',
#     'CHANYEOL FANCLUB\n',
#     '1\n',
#     '653235.jpg\n',
#     'Great run today in $T$ in Glenwood Springs , CO .\n',
#     'White River National Forest\n',
#     '1\n',
#     '478494.jpg\n',
#     'Great run today in White River National Forest in $T$ , CO .\n',
#     'Glenwood Springs\n',
#     '0\n',
#     '478494.jpg\n',
#     'Expressive portraits of people from all walks of life by $T$ \n',
#     'Jonathan Willis\n',
#     '0\n',
#     '1993706.jpg\n',
#     'RT @ DierksBentley : $T$ : You lit it up tonight ! # SoldierField\n',
#     'CHICAGO\n',
#     '0\n',
#     '523563.jpg\n',
#     'RT @ iArunJ : Interesting piece by @ Sportingabhi : Eng v $T$ : stats suggest Fletcher should go\n',
#     'India\n',
#     '0\n',
#     '728939.jpg\n',
#     'RT @ iArunJ : Interesting piece by @ Sportingabhi : Eng v India : stats suggest $T$ should go\n',
#     'Fletcher\n',
#     '0\n',
#     '728939.jpg\n',
#     '$T$ Updates AdWords Keyword Qual . . . # google # SEO # Socialmedia\n',
#     'Google\n',
#     '0\n',
#     '841659.jpg\n',
#     'Google Updates $T$ Keyword Qual . . . # google # SEO # Socialmedia\n',
#     'AdWords\n',
#     '0\n',
#     '841659.jpg\n',
#     'Google Updates AdWords Keyword Qual . . . $T$ # SEO # Socialmedia\n',
#     '# google\n',
#     '0\n',
#     '841659.jpg\n',
#     'RT @ l elwood : $T$ shares the importance of partnerships at # OTEW2014 # tl\n',
#     'Graham Pullen\n',
#     '0\n',
#     '734179.jpg\n',
#     'RT @ FRANCE24 : New documents shed light on $T$ failings 20 years on\n',
#     'Srebrenica\n',
#     '-1\n',
#     '12849.jpg\n',
#     'RT @ TheOnion : $T$ Admits Role In 1985 Coup To Oust David Lee Roth\n',
#     'CIA\n',
#     '-1\n',
#     '34586.jpg\n',
#     'RT @ TheOnion : CIA Admits Role In 1985 Coup To Oust $T$ \n',
#     'David Lee Roth\n',
#     '0\n',
#     '34586.jpg\n',
#     'RT @ SteveMariucci : Gettin ready for the Draft at Raos - - $T$ ! !\n',
#     'NYC\n',
#     '1\n',
#     '583416.jpg\n',
#     'RT @ nytimes : How $T$ is worse off than the U . S . in the Great Depression\n',
#     'Greece\n',
#     '-1\n',
#     '48509.jpg\n',
#     'RT @ nytimes : How Greece is worse off than the U . S . in the $T$ \n',
#     'Great Depression\n',
#     '-1\n',
#     '48509.jpg\n',
#     'Man Made Frozen Waterfall from Hot Water Tap Left on all Winter # Crazy # Bizarre $T$ \n',
#     '# China\n',
#     '0\n',
#     '209240.jpg\n',
#     'Awesome weather at $T$ !\n',
#     'Laguna Beach\n',
#     '1\n',
#     '1767740.jpg\n',
#     '$T$ quarterbacks Jimmy Clausen and Jay Cutler take the field to face the Niners in SF\n',
#     '# Bears\n',
#     '1\n',
#     '73226.jpg\n',
#     '# Bears quarterbacks $T$ and Jay Cutler take the field to face the Niners in SF\n',
#     'Jimmy Clausen\n',
#     '1\n',
#     '73226.jpg\n',
#     '# Bears quarterbacks Jimmy Clausen and $T$ take the field to face the Niners in SF\n',
#     'Jay Cutler\n',
#     '1\n',
#     '73226.jpg\n',
#     '# Bears quarterbacks Jimmy Clausen and Jay Cutler take the field to face the $T$ in SF\n',
#     'Niners\n',
#     '0\n',
#     '73226.jpg\n',
#     '$T$ gets the gameplan : more pictures # Bulls\n',
#     'Kirk Hinrich\n',
#     '0\n',
#     '73085.jpg\n',
#     'Kirk Hinrich gets the gameplan : more pictures $T$ \n',
#     '# Bulls\n',
#     '0\n',
#     '73085.jpg\n',
#     'RT @ ImitationGame : $T$ acknowledges Alan Turing as a true hero . # ImitationGame\n',
#     'The LGBT community\n',
#     '0\n',
#     '240939.jpg\n',
#     'RT @ ImitationGame : The LGBT community acknowledges $T$ as a true hero . # ImitationGame\n',
#     'Alan Turing\n',
#     '1\n',
#     '240939.jpg\n',
#     '5 years ago today I was in $T$ on the Picasso , barely ready for the first ballot # chicago2016 # backthebid\n',
#     'Daley Plaza\n',
#     '0\n',
#     '73052.jpg\n',
#     '5 years ago today I was in Daley Plaza on the $T$ , barely ready for the first ballot # chicago2016 # backthebid\n',
#     'Picasso\n',
#     '0\n',
#     '73052.jpg\n',
#     '$T$ on the front page of @ chicagotribune today . Photos and Blair Kamin review :\n',
#     '# 1WTC\n',
#     '0\n',
#     '72904.jpg\n',
#     '# 1WTC on the front page of @ chicagotribune today . Photos and $T$ review :\n',
#     'Blair Kamin\n',
#     '0\n',
#     '72904.jpg\n',
#     'RT @ HuffPostSports : Legendary $T$ dunker Darryl Dawkins dead at 58\n',
#     'NBA\n',
#     '0\n',
#     '159708.jpg\n',
#     'RT @ HuffPostSports : Legendary NBA dunker $T$ dead at 58\n',
#     'Darryl Dawkins\n',
#     '-1\n',
#     '159708.jpg\n',
#     'RT @ Ahmed91Gooner : $T$ is back . ( Via @ Stuart PhotoAFC )\n',
#     'Koscielny\n',
#     '1\n',
#     '1444667.jpg\n',
#     'RT @ PietBrouwerET : Follow our progress on $T$ via a live webcam\n',
#     'Acta Orion\n',
#     '0\n',
#     '72145.jpg\n',
#     'RT @ AngrygirLcomics : This is a great pic of $T$ \n',
#     'Benedict Cumberbatch\n',
#     '0\n',
#     '2014884.jpg\n',
#     'RT @ 5SOSPHTeam : $T$ is going to be on Ellen . Here are the channels and their schedules .\n',
#     '5SOS\n',
#     '0\n',
#     '1942382.jpg\n',
#     'RT @ 5SOSPHTeam : 5SOS is going to be on $T$ . Here are the channels and their schedules .\n',
#     'Ellen\n',
#     '0\n',
#     '1942382.jpg\n',
#     'Top 10 Buildings for Luxury Living in $T$ \n',
#     'NYC\n',
#     '0\n',
#     '116293.jpg\n',
#     'RT @ girlposts : I still miss this $T$ though\n',
#     'Disney channel\n',
#     '1\n',
#     '15883.jpg\n',
#     'RT @ LittleMix : Hurry up $T$ ! ! ! ! We got a meeting soon ! Xx\n',
#     'Leigh\n',
#     '1\n',
#     '444038.jpg\n',
#     'RT @ allkpop : 2013 revenue from $T$ , YG , and JYP Entertainment revealed\n',
#     'SM\n',
#     '0\n',
#     '7498.jpg\n',
#     'RT @ allkpop : 2013 revenue from SM , $T$ , and JYP Entertainment revealed\n',
#     'YG\n',
#     '0\n',
#     '7498.jpg\n',
#     'RT @ allkpop : 2013 revenue from SM , YG , and $T$ Entertainment revealed\n',
#     'JYP\n',
#     '0\n',
#     '7498.jpg\n',
#     'RT @ nflnetwork : Up Next - A Football Life : $T$ . STREAM :\n',
#     'Ricky Williams\n',
#     '0\n',
#     '319676.jpg\n',
#     'RT @ SuicideGirls : $T$ is a photographer from Brazil ! Learn more about this babe at\n',
#     'Zad Suicide\n',
#     '0\n',
#     '1087217.jpg\n',
#     'RT @ SuicideGirls : Zad Suicide is a photographer from $T$ ! Learn more about this babe at\n',
#     'Brazil\n',
#     '0\n',
#     '1087217.jpg\n',
#     'RT @ TVGuide : Check out a first look at $T$ as Reverse Flash ! # TheFlash\n',
#     'Tom Cavanagh\n',
#     '1\n',
#     '319246.jpg\n',
#     'RT @ TVGuide : Check out a first look at Tom Cavanagh as $T$ ! # TheFlash\n',
#     'Reverse Flash\n',
#     '1\n',
#     '319246.jpg\n',
#     '$T$ enjoys a birthday bath - - and a blue snout . Join us this weekend : Photo by Sandi Wong\n',
#     'Jillian\n',
#     '1\n',
#     '1285253.jpg\n',
#     'Jillian enjoys a birthday bath - - and a blue snout . Join us this weekend : Photo by $T$ \n',
#     'Sandi Wong\n',
#     '0\n',
#     '1285253.jpg\n',
#     '@ NationalZoo # PandaCam2 Depressed by the shutdown , $T$ the Panda started off her morning with a large glass of wine\n',
#     'Lucy\n',
#     '-1\n',
#     '547370.jpg\n',
#     'This beautiful RL bag is in $T$ , China .\n',
#     'Macau\n',
#     '0\n',
#     '136920.jpg\n',
#     'This beautiful RL bag is in Macau , $T$ .\n',
#     'China\n',
#     '0\n',
#     '136920.jpg\n',
#     ...],
#    ['RT @ ltsChuckBass : $T$ is everything # MCM',
#     'Chuck Bass',
#     '1',
#     '1860693.jpg',
#     'RT @ ltsChuckBass : Chuck Bass is everything $T$ ',
#     '# MCM',
#     '0',
#     '1860693.jpg',
#     '$T$ September 7 - - - - Shut Down New York City',
#     'Millions For Trayvon',
#     '0',
#     '195984.jpg',
#     'Millions For Trayvon September 7 - - - - Shut Down $T$ ',
#     'New York City',
#     '-1',
#     '195984.jpg',
#     'Me as $T$ .',
#     'John Lennon',
#     '1',
#     '871618.jpg',
#     'Former $T$ boss Rod Petricevic will be released from jail next month .',
#     'Bridgecorp',
#     '0',
#     '280704.jpg',
#     'Former Bridgecorp boss $T$ will be released from jail next month .',
#     'Rod Petricevic',
#     '-1',
#     '280704.jpg',
#     'Tried $T$ for an out of game Halo 5 experience and holograms are totally awesome # E3',
#     'HoloLens',
#     '1',
#     '638395.jpg',
#     'Tried HoloLens for an out of game Halo 5 experience and holograms are totally awesome $T$ ',
#     '# E3',
#     '1',
#     '638395.jpg',
#     'RT @ BBC Travel : Chasing light and shadows in beautiful $T$ : # architecture',
#     '# Iran',
#     '1',
#     '138186.jpg',
#     'RT @ MySportsLegion : $T$ is already wearing a Johnny Football Browns jersey . ( via @ WFNYScott )',
#     'LeBron James',
#     '0',
#     '512435.jpg',
#     'RT @ MySportsLegion : LeBron James is already wearing a $T$ Football Browns jersey . ( via @ WFNYScott )',
#     'Johnny',
#     '0',
#     '512435.jpg',
#     'RT @ MySportsLegion : LeBron James is already wearing a Johnny $T$ jersey . ( via @ WFNYScott )',
#     'Football Browns',
#     '0',
#     '512435.jpg',
#     'RT @ arasmusKTVU : # BaytoBreakers race delayed because of unstable arch at $T$ ( per Mayors office ) # KTVU',
#     'Hayes st hill',
#     '-1',
#     '722168.jpg',
#     'RT @ arasmusKTVU : # BaytoBreakers race delayed because of unstable arch at Hayes st hill ( per Mayors office ) $T$ ',
#     '# KTVU',
#     '0',
#     '722168.jpg',
#     '$T$ gov candidate Kirk Dillard greets supporters as the race tightens on primary election night',
#     'GOP',
#     '1',
#     '74090.jpg',
#     'GOP gov candidate $T$ greets supporters as the race tightens on primary election night',
#     'Kirk Dillard',
#     '1',
#     '74090.jpg',
#     'RT @ BI Defense : $T$ scrambles Typhoon jets to see off Russian bombers',
#     'Britain',
#     '0',
#     '73066.jpg',
#     '$T$ tells # Congobrazza to do more to attract foreign companies in agriculture',
#     'UNCTAD',
#     '0',
#     '623109.jpg',
#     'Hanging out with $T$ # Blackhawks # WinterClassic',
#     'Corey',
#     '1',
#     '71953.jpg',
#     'Hanging out with Corey $T$ # WinterClassic',
#     '# Blackhawks',
#     '1',
#     '71953.jpg',
#     'RT @ ESPN FirstTake : I think he should STAY in $T$ . - @ stephenasmith # RevisFuture',
#     'New England',
#     '0',
#     '1748621.jpg',
#     '$T$ holds its own mini - parade around 70th anniversary of WWII victory : https : t . co JNz6Ocp595',
#     'Taiwan',
#     '0',
#     '559998.jpg',
#     'Taiwan holds its own mini - parade around 70th anniversary of $T$ victory : https : t . co JNz6Ocp595',
#     'WWII',
#     '1',
#     '559998.jpg',
#     '. @ TheSwonBrothers @ SwonBrothers Performing July 24th at the $T$ ',
#     'Fayette County Fair',
#     '0',
#     '578058.jpg',
#     'RT @ nytimes : A French take on tagine , from $T$ ',
#     'Daniel Boulud',
#     '0',
#     '117833.jpg',
#     'RT @ thehill : Poll : $T$ amp Trump lead 2016 GOP field',
#     'Bush',
#     '0',
#     '116990.jpg',
#     'RT @ thehill : Poll : Bush amp $T$ lead 2016 GOP field',
#     'Trump',
#     '0',
#     '116990.jpg',
#     'RT @ thehill : Poll : Bush amp Trump lead 2016 $T$ field',
#     'GOP',
#     '0',
#     '116990.jpg',
#     'RT @ business : $T$ is now almost twice as valuable as the next biggest company on Earth',
#     'Apple',
#     '1',
#     '38154.jpg',
#     'RT @ barrabest : A great photo of $T$ . Taken @ DeeGregg .',
#     '# Belfast City Hall',
#     '1',
#     '488240.jpg',
#     "$T$ celebrates his goal , but the good times didn ' t last . # Blackhawks fall :",
#     'Brent Seabrook',
#     '1',
#     '70943.jpg',
#     "Brent Seabrook celebrates his goal , but the good times didn ' t last . $T$ fall :",
#     '# Blackhawks',
#     '-1',
#     '70943.jpg',
#     'This is a fantastic idea - a purifying wave pool for surfers built into the $T$ :',
#     'Rotterdam canals',
#     '0',
#     '569602.jpg',
#     "RT @ Cosmopolitan : It ' s OK if these sexy shirtless photos of TFIOS ' $T$ makes you . . . feel things",
#     'Ansel Elgort',
#     '0',
#     '73141.jpg',
#     'RT @ BarackObama : # ClimateChangeIsReal . So are the actions $T$ is taking to tackle it .',
#     'President Obama',
#     '1',
#     '1490725.jpg',
#     'RT @ Swiftwriting : $T$ looking absolutely flawless at the BBC Teen Awards .',
#     'Taylor',
#     '1',
#     '37498.jpg',
#     'RT @ Swiftwriting : Taylor looking absolutely flawless at the $T$ .',
#     'BBC Teen Awards',
#     '0',
#     '37498.jpg',
#     '@ Louis Garneau Join I Am Able : a handicap cycling team that originated in $T$ .',
#     'Rwanda',
#     '0',
#     '446463.jpg',
#     'RT @ NATO : $T$ appoints @ jensstoltenberg as # NATO SG as of October 1st 2014',
#     'North Atlantic Council',
#     '0',
#     '68397.jpg',
#     'RT @ NATO : North Atlantic Council appoints @ jensstoltenberg as $T$ SG as of October 1st 2014',
#     '# NATO',
#     '0',
#     '68397.jpg',
#     'RT @ htmgarcia : Drones are banned in $T$ - I expected this could be a gossip # Japan',
#     '# Hiroshima Peace Memorial Park',
#     '-1',
#     '617578.jpg',
#     'RT @ htmgarcia : Drones are banned in # Hiroshima Peace Memorial Park - I expected this could be a gossip $T$ ',
#     '# Japan',
#     '0',
#     '617578.jpg',
#     'Results from @ IronTrac for $T$ @ # Ironman # Raleigh 70 . 3 2014',
#     'Christine Allen',
#     '0',
#     '638357.jpg',
#     'Results from @ IronTrac for Christine Allen @ # Ironman $T$ 70 . 3 2014',
#     '# Raleigh',
#     '0',
#     '638357.jpg',
#     '# TBT 2 months ago today this pic was taken during # Sochi2014 final . What was @ SledSweeney13 saying to $T$ ?',
#     'Tyler Carron',
#     '0',
#     '701488.jpg',
#     'Check out the summer issue of @ familytraveller they give you the best tips for a family to discover $T$ in 48h !',
#     'Marrakech',
#     '1',
#     '1326656.jpg',
#     'RT @ HistoryPixs : $T$ when she was only 16 years old .',
#     'Angelina Jolie',
#     '0',
#     '1953977.jpg',
#     'RT @ WildWiseDevon : In the spring , at the end of the day , you should smell like dirt . $T$ ',
#     'Margaret Atwood',
#     '0',
#     '521612.jpg',
#     'RT @ MrFox13 : $T$ need to go here with the boys',
#     'Defo',
#     '0',
#     '1336838.jpg',
#     'Swan upping : first stop $T$ , Tower Bridge ( Tower and Olympic rings in the background )',
#     'Hermitage Warf',
#     '0',
#     '1109405.jpg',
#     'Swan upping : first stop Hermitage Warf , $T$ ( Tower and Olympic rings in the background )',
#     'Tower Bridge',
#     '0',
#     '1109405.jpg',
#     'Swan upping : first stop Hermitage Warf , Tower Bridge ( $T$ and Olympic rings in the background )',
#     'Tower',
#     '0',
#     '1109405.jpg',
#     'Swan upping : first stop Hermitage Warf , Tower Bridge ( Tower and $T$ rings in the background )',
#     'Olympic',
#     '0',
#     '1109405.jpg',
#     'This passes for snow in $T$ # blackhawks # winterclassic',
#     'DC',
#     '0',
#     '72008.jpg',
#     'This passes for snow in DC $T$ # winterclassic',
#     '# blackhawks',
#     '0',
#     '72008.jpg',
#     'RT @ thinkprogress : $T$ and the invisible plight of black women in the justice system',
#     'Sandra Bland',
#     '0',
#     '570930.jpg',
#     'RT @ LadyGagaNowNet : $T$ getting a drink at the bar at The Oscars 2014 .',
#     'Lady Gaga',
#     '0',
#     '1472725.jpg',
#     'RT @ LadyGagaNowNet : Lady Gaga getting a drink at $T$ bar at The Oscars 2014 .',
#     'the',
#     '0',
#     '1472725.jpg',
#     'RT @ LadyGagaNowNet : Lady Gaga getting a drink at the bar at $T$ 2014 .',
#     'The Oscars',
#     '0',
#     '1472725.jpg',
#     '@ BetterCallSaul : Happy birthday , $T$ ! Happy birthday , master !',
#     'Vince Gilligan',
#     '1',
#     '34793.jpg',
#     '$T$ and SDU Campus Kolding have been awarded The International Architecture Award',
#     'Moesgaard Museum',
#     '1',
#     '1075863.jpg',
#     'Moesgaard Museum and $T$ have been awarded The International Architecture Award',
#     'SDU Campus Kolding',
#     '1',
#     '1075863.jpg',
#     'Moesgaard Museum and SDU Campus Kolding have been awarded $T$ ',
#     'The International Architecture Award',
#     '0',
#     '1075863.jpg',
#     'RT @ AnimalsAsia : Special Report : Dog meat wars : 5 stories that shocked $T$ ',
#     'Vietnam',
#     '0',
#     '1027114.jpg',
#     'RT @ Steve OS : $T$ Achievement Unlocked',
#     'DeAndre Jordan',
#     '1',
#     '21311.jpg',
#     'BREAKING NEWS : $T$ youngster Junior Malanda has died in a car accident , according to BILD .',
#     'Wolfsburg',
#     '0',
#     '669523.jpg',
#     'BREAKING NEWS : Wolfsburg youngster $T$ has died in a car accident , according to BILD .',
#     'Junior Malanda',
#     '-1',
#     '669523.jpg',
#     'BREAKING NEWS : Wolfsburg youngster Junior Malanda has died in a car accident , according to $T$ .',
#     'BILD',
#     '0',
#     '669523.jpg',
#     'RT @ zgarrison3 : @ ukghosthunting $T$ According to Herman Klein , it was taken in 1898 : )',
#     'The Elixir Of Youth',
#     '0',
#     '659252.jpg',
#     'RT @ zgarrison3 : @ ukghosthunting The Elixir Of Youth According to $T$ , it was taken in 1898 : )',
#     'Herman Klein',
#     '0',
#     '659252.jpg',
#     'One week to go until our visit to the Australian Embassy in $T$ for morning tea with the Ambassador .',
#     'Indonesia',
#     '0',
#     '130789.jpg',
#     'RT @ BobBuckhorn : $T$ opens new lacrosse stadium . Generous donation from Vince Namoli made it happen .',
#     'U of Tampa',
#     '1',
#     '70471.jpg',
#     'RT @ BobBuckhorn : U of Tampa opens new lacrosse stadium . Generous donation from $T$ made it happen .',
#     'Vince Namoli',
#     '1',
#     '70471.jpg',
#     '@ harunmaruf : Outside # BuloMarer , $T$ commander Gen . Dick Olum finds a souvenir after al # shabab were overwhelmed !',
#     'AMISOM',
#     '0',
#     '1009286.jpg',
#     '@ harunmaruf : Outside # BuloMarer , AMISOM commander $T$ . Dick Olum finds a souvenir after al # shabab were overwhelmed !',
#     'Gen',
#     '0',
#     '1009286.jpg',
#     '@ harunmaruf : Outside # BuloMarer , AMISOM commander Gen . $T$ finds a souvenir after al # shabab were overwhelmed !',
#     'Dick Olum',
#     '0',
#     '1009286.jpg',
#     'RT @ buziosglobalusa : $T$ in # Tokyo Station # HappyHolidays',
#     '# Christmas',
#     '1',
#     '500370.jpg',
#     'RT @ buziosglobalusa : # Christmas in $T$ # HappyHolidays',
#     '# Tokyo Station',
#     '1',
#     '500370.jpg',
#     'So sorry to hear about $T$ and Kris Medlen needing # TommyJohn again . Great pitchers .',
#     'Jarrod Parker',
#     '-1',
#     '886689.jpg',
#     'So sorry to hear about Jarrod Parker and $T$ needing # TommyJohn again . Great pitchers .',
#     'Kris Medlen',
#     '-1',
#     '886689.jpg',
#     'RT @ InsideHoops : $T$ update :',
#     'DeAndre Jordan',
#     '0',
#     '480117.jpg',
#     'Honored to be here in $T$ @ jworldwatch IWitness Award given to Intel 4 commitment to only use conflict free minerals',
#     'LA',
#     '1',
#     '13680.jpg',
#     'Honored to be here in LA @ jworldwatch IWitness Award given to $T$ commitment to only use conflict free minerals',
#     'Intel 4',
#     '1',
#     '13680.jpg',
#     'Second awesome event of the day : Open Schools $T$ launch @ GroundTruthIn @ DGateway @ OpenGovHub',
#     'Kenya',
#     '1',
#     '1717237.jpg',
#     'RT @ favecrushes : $T$ before and after',
#     'Aaron Johnson',
#     '0',
#     '1787734.jpg',
#     'RT @ MarinaConcert : $T$ meeting diamonds after the show tonight ! ! !',
#     'Marina',
#     '1',
#     '65352.jpg',
#     '# Cancer patient $T$ and family pose with @ NdamukongSuh for the # GameOnCancer fundraising campaign .',
#     'Michael Gabriel',
#     '0',
#     '557517.jpg',
#     'RT @ THEMAZElSACODE : RT if $T$ is your favorite character in The Maze Runner trilogy !',
#     'Newt',
#     '1',
#     '515898.jpg',
#     'This is where $T$ Lincoln was not only born , but raised . Amy Schumer at Lincoln Center',
#     'Abe',
#     '0',
#     '2077969.jpg',
#     'This is where Abe $T$ was not only born , but raised . Amy Schumer at Lincoln Center',
#     'Lincoln',
#     '0',
#     '2077969.jpg',
#     'This is where Abe Lincoln was not only born , but raised . $T$ at Lincoln Center',
#     'Amy Schumer',
#     '0',
#     '2077969.jpg',
#     'This is where Abe Lincoln was not only born , but raised . Amy Schumer at $T$ ',
#     'Lincoln Center',
#     '0',
#     '2077969.jpg',
#     'RT @ 1D Beards : Real life $T$ ? I think so . - Blaze',
#     'Peter Pan',
#     '0',
#     '1908966.jpg',
#     'RT @ chicagotribune : Update : $T$ says no planes in U . S . destined to cross Midwest can depart until at least 10 a . m . h',
#     'FAA',
#     '-1',
#     '73134.jpg',
#     'RT @ chicagotribune : Update : FAA says no planes in U . S . destined to cross $T$ can depart until at least 10 a . m . h',
#     'Midwest',
#     '0',
#     '73134.jpg',
#     'RT @ EarthBeauties : $T$ , California',
#     'San Francisco',
#     '0',
#     '525824.jpg',
#     'RT @ EarthBeauties : San Francisco , $T$ ',
#     'California',
#     '0',
#     '525824.jpg',
# ...
#     'Preparing the sand at Hayes Beach for $T$ weekend . Chicago beaches open Saturday !',
#     'Memorial Day',
#     '0',
#     '73853.jpg',
#     'Preparing the sand at Hayes Beach for Memorial Day weekend . $T$ beaches open Saturday !',
#     'Chicago',
#     '0',
#     '73853.jpg',
#     'RT @ ShitBsbPlyrsSay : The $T$ made the rookies go get Coffee',
#     'Cardinals',
#     '0',
#     '74167.jpg',
#     'RT @ AjaySharmaFCO : Delighted to be back in $T$ and that the Embassy has reopened . # UK # Iran',
#     'Tehran',
#     '1',
#     '1779633.jpg',
#     'RT @ AjaySharmaFCO : Delighted to be back in Tehran and that the Embassy has reopened . $T$ # Iran',
#     '# UK',
#     '0',
#     '1779633.jpg',
#     'RT @ AjaySharmaFCO : Delighted to be back in Tehran and that the Embassy has reopened . # UK $T$ ',
#     '# Iran',
#     '0',
#     '1779633.jpg',
#     'RT @ StephanieArts : My drawing of @ LaurenSocha as $T$ . Hope you like it ! # Misfits # misstheshow',
#     'Kelly Bailey',
#     '0',
#     '1084327.jpg',
#     'RT @ StephanieArts : My drawing of @ LaurenSocha as Kelly Bailey . Hope you like it ! $T$ # misstheshow',
#     '# Misfits',
#     '0',
#     '1084327.jpg',
#     'RT @ 1DInfectionMNL : $T$ from January 2014 to December 2014 # 14MomentsOfZayn',
#     'Zayn',
#     '0',
#     '1719707.jpg',
#     'RT @ CHANBAEKUNION : VOTE FOR BAEKHYUN AS $T$ PRESIDENT . HAHAHAHHAA : D ( cr . garcon )',
#     'CHANYEOL FANCLUB',
#     '1',
#     '653235.jpg',
#     'Great run today in $T$ in Glenwood Springs , CO .',
#     'White River National Forest',
#     '1',
#     '478494.jpg',
#     'Great run today in White River National Forest in $T$ , CO .',
#     'Glenwood Springs',
#     '0',
#     '478494.jpg',
#     'Expressive portraits of people from all walks of life by $T$ ',
#     'Jonathan Willis',
#     '0',
#     '1993706.jpg',
#     'RT @ DierksBentley : $T$ : You lit it up tonight ! # SoldierField',
#     'CHICAGO',
#     '0',
#     '523563.jpg',
#     'RT @ iArunJ : Interesting piece by @ Sportingabhi : Eng v $T$ : stats suggest Fletcher should go',
#     'India',
#     '0',
#     '728939.jpg',
#     'RT @ iArunJ : Interesting piece by @ Sportingabhi : Eng v India : stats suggest $T$ should go',
#     'Fletcher',
#     '0',
#     '728939.jpg',
#     '$T$ Updates AdWords Keyword Qual . . . # google # SEO # Socialmedia',
#     'Google',
#     '0',
#     '841659.jpg',
#     'Google Updates $T$ Keyword Qual . . . # google # SEO # Socialmedia',
#     'AdWords',
#     '0',
#     '841659.jpg',
#     'Google Updates AdWords Keyword Qual . . . $T$ # SEO # Socialmedia',
#     '# google',
#     '0',
#     '841659.jpg',
#     'RT @ l elwood : $T$ shares the importance of partnerships at # OTEW2014 # tl',
#     'Graham Pullen',
#     '0',
#     '734179.jpg',
#     'RT @ FRANCE24 : New documents shed light on $T$ failings 20 years on',
#     'Srebrenica',
#     '-1',
#     '12849.jpg',
#     'RT @ TheOnion : $T$ Admits Role In 1985 Coup To Oust David Lee Roth',
#     'CIA',
#     '-1',
#     '34586.jpg',
#     'RT @ TheOnion : CIA Admits Role In 1985 Coup To Oust $T$ ',
#     'David Lee Roth',
#     '0',
#     '34586.jpg',
#     'RT @ SteveMariucci : Gettin ready for the Draft at Raos - - $T$ ! !',
#     'NYC',
#     '1',
#     '583416.jpg',
#     'RT @ nytimes : How $T$ is worse off than the U . S . in the Great Depression',
#     'Greece',
#     '-1',
#     '48509.jpg',
#     'RT @ nytimes : How Greece is worse off than the U . S . in the $T$ ',
#     'Great Depression',
#     '-1',
#     '48509.jpg',
#     'Man Made Frozen Waterfall from Hot Water Tap Left on all Winter # Crazy # Bizarre $T$ ',
#     '# China',
#     '0',
#     '209240.jpg',
#     'Awesome weather at $T$ !',
#     'Laguna Beach',
#     '1',
#     '1767740.jpg',
#     '$T$ quarterbacks Jimmy Clausen and Jay Cutler take the field to face the Niners in SF',
#     '# Bears',
#     '1',
#     '73226.jpg',
#     '# Bears quarterbacks $T$ and Jay Cutler take the field to face the Niners in SF',
#     'Jimmy Clausen',
#     '1',
#     '73226.jpg',
#     '# Bears quarterbacks Jimmy Clausen and $T$ take the field to face the Niners in SF',
#     'Jay Cutler',
#     '1',
#     '73226.jpg',
#     '# Bears quarterbacks Jimmy Clausen and Jay Cutler take the field to face the $T$ in SF',
#     'Niners',
#     '0',
#     '73226.jpg',
#     '$T$ gets the gameplan : more pictures # Bulls',
#     'Kirk Hinrich',
#     '0',
#     '73085.jpg',
#     'Kirk Hinrich gets the gameplan : more pictures $T$ ',
#     '# Bulls',
#     '0',
#     '73085.jpg',
#     'RT @ ImitationGame : $T$ acknowledges Alan Turing as a true hero . # ImitationGame',
#     'The LGBT community',
#     '0',
#     '240939.jpg',
#     'RT @ ImitationGame : The LGBT community acknowledges $T$ as a true hero . # ImitationGame',
#     'Alan Turing',
#     '1',
#     '240939.jpg',
#     '5 years ago today I was in $T$ on the Picasso , barely ready for the first ballot # chicago2016 # backthebid',
#     'Daley Plaza',
#     '0',
#     '73052.jpg',
#     '5 years ago today I was in Daley Plaza on the $T$ , barely ready for the first ballot # chicago2016 # backthebid',
#     'Picasso',
#     '0',
#     '73052.jpg',
#     '$T$ on the front page of @ chicagotribune today . Photos and Blair Kamin review :',
#     '# 1WTC',
#     '0',
#     '72904.jpg',
#     '# 1WTC on the front page of @ chicagotribune today . Photos and $T$ review :',
#     'Blair Kamin',
#     '0',
#     '72904.jpg',
#     'RT @ HuffPostSports : Legendary $T$ dunker Darryl Dawkins dead at 58',
#     'NBA',
#     '0',
#     '159708.jpg',
#     'RT @ HuffPostSports : Legendary NBA dunker $T$ dead at 58',
#     'Darryl Dawkins',
#     '-1',
#     '159708.jpg',
#     'RT @ Ahmed91Gooner : $T$ is back . ( Via @ Stuart PhotoAFC )',
#     'Koscielny',
#     '1',
#     '1444667.jpg',
#     'RT @ PietBrouwerET : Follow our progress on $T$ via a live webcam',
#     'Acta Orion',
#     '0',
#     '72145.jpg',
#     'RT @ AngrygirLcomics : This is a great pic of $T$ ',
#     'Benedict Cumberbatch',
#     '0',
#     '2014884.jpg',
#     'RT @ 5SOSPHTeam : $T$ is going to be on Ellen . Here are the channels and their schedules .',
#     '5SOS',
#     '0',
#     '1942382.jpg',
#     'RT @ 5SOSPHTeam : 5SOS is going to be on $T$ . Here are the channels and their schedules .',
#     'Ellen',
#     '0',
#     '1942382.jpg',
#     'Top 10 Buildings for Luxury Living in $T$ ',
#     'NYC',
#     '0',
#     '116293.jpg',
#     'RT @ girlposts : I still miss this $T$ though',
#     'Disney channel',
#     '1',
#     '15883.jpg',
#     'RT @ LittleMix : Hurry up $T$ ! ! ! ! We got a meeting soon ! Xx',
#     'Leigh',
#     '1',
#     '444038.jpg',
#     'RT @ allkpop : 2013 revenue from $T$ , YG , and JYP Entertainment revealed',
#     'SM',
#     '0',
#     '7498.jpg',
#     'RT @ allkpop : 2013 revenue from SM , $T$ , and JYP Entertainment revealed',
#     'YG',
#     '0',
#     '7498.jpg',
#     'RT @ allkpop : 2013 revenue from SM , YG , and $T$ Entertainment revealed',
#     'JYP',
#     '0',
#     '7498.jpg',
#     'RT @ nflnetwork : Up Next - A Football Life : $T$ . STREAM :',
#     'Ricky Williams',
#     '0',
#     '319676.jpg',
#     'RT @ SuicideGirls : $T$ is a photographer from Brazil ! Learn more about this babe at',
#     'Zad Suicide',
#     '0',
#     '1087217.jpg',
#     'RT @ SuicideGirls : Zad Suicide is a photographer from $T$ ! Learn more about this babe at',
#     'Brazil',
#     '0',
#     '1087217.jpg',
#     'RT @ TVGuide : Check out a first look at $T$ as Reverse Flash ! # TheFlash',
#     'Tom Cavanagh',
#     '1',
#     '319246.jpg',
#     'RT @ TVGuide : Check out a first look at Tom Cavanagh as $T$ ! # TheFlash',
#     'Reverse Flash',
#     '1',
#     '319246.jpg',
#     '$T$ enjoys a birthday bath - - and a blue snout . Join us this weekend : Photo by Sandi Wong',
#     'Jillian',
#     '1',
#     '1285253.jpg',
#     'Jillian enjoys a birthday bath - - and a blue snout . Join us this weekend : Photo by $T$ ',
#     'Sandi Wong',
#     '0',
#     '1285253.jpg',
#     '@ NationalZoo # PandaCam2 Depressed by the shutdown , $T$ the Panda started off her morning with a large glass of wine',
#     'Lucy',
#     '-1',
#     '547370.jpg',
#     'This beautiful RL bag is in $T$ , China .',
#     'Macau',
#     '0',
#     '136920.jpg',
#     'This beautiful RL bag is in Macau , $T$ .',
#     'China',
#     '0',
#     '136920.jpg',
#     ...])],
#  [''],
#  [['R',
#    'C',
#    '1',
#    '1',
#    'R',
#    '#',
#    '0',
#    '1',
#    '$',
#    'M',
#    '0',
#    '1',
#    'M',
#    'N',
#    '-',
#    '1',
#    'M',
#    'J',
#    '1',
#    '8',
#    'F',
#    'B',
#    '0',
#    '2',
#    'F',
#    'R',
#    '-',
#    '2',
#    'T',
#    'H',
#    '1',
#    '6',
#    'T',
#    '#',
#    '1',
#    '6',
#    'R',
#    '#',
#    '1',
#    '1',
#    'R',
#    'L',
#    '0',
#    '5',
#    'R',
#    'J',
#    '0',
#    '5',
#    'R',
#    'F',
#    '0',
#    '5',
#    'R',
#    'H',
#    '-',
#    '7',
#    'R',
#    '#',
#    '0',
#    '7',
#    '$',
#    'G',
#    '1',
#    '7',
#    'G',
#    'K',
#    '1',
#    '7',
#    'R',
#    'B',
#    '0',
#    '7',
#    '$',
#    'U',
#    '0',
#    '6',
#    'H',
#    'C',
#    '1',
#    '7',
#    'H',
#    '#',
#    '1',
#    '7',
#    'R',
#    'N',
#    '0',
#    '1',
#    '$',
#    'T',
#    '0',
#    '5',
#    'T',
#    'W',
#    '1',
#    '5',
#    '.',
#    'F',
#    '0',
#    '5',
#    'R',
#    'D',
#    '0',
#    '1',
#    'R',
#    'B',
#    '0',
#    '1',
#    'R',
#    'T',
#    '0',
#    '1',
#    'R',
#    'G',
#    '0',
#    '1',
#    'R',
#    'A',
#    '1',
#    '3',
#    'R',
#    '#',
#    '1',
#    '4',
#    '$',
#    'B',
#    '1',
#    '7',
#    'B',
#    '#',
#    '-',
#    '7',
#    'T',
#    'R',
#    '0',
#    '5',
#    'R',
#    'A',
#    '0',
#    '7',
#    'R',
#    'P',
#    '1',
#    '1',
#    'R',
#    'T',
#    '1',
#    '3',
#    'R',
#    'B',
#    '0',
#    '3',
#    '@',
#    'R',
#    '0',
#    '4',
#    'R',
#    'N',
#    '0',
#    '6',
#    'R',
#    '#',
#    '0',
#    '6',
#    'R',
#    '#',
#    '-',
#    '6',
#    'R',
#    '#',
#    '0',
#    '6',
#    'R',
#    'C',
#    '0',
#    '6',
#    'R',
#    '#',
#    '0',
#    '6',
#    '#',
#    'T',
#    '0',
#    '7',
#    'C',
#    'M',
#    '1',
#    '1',
#    'R',
#    'A',
#    '0',
#    '1',
#    'R',
#    'M',
#    '0',
#    '5',
#    'R',
#    'D',
#    '0',
#    '1',
#    'S',
#    'H',
#    '0',
#    '1',
#    'S',
#    'T',
#    '0',
#    '1',
#    'S',
#    'T',
#    '0',
#    '1',
#    'S',
#    'O',
#    '0',
#    '1',
#    'T',
#    'D',
#    '0',
#    '7',
#    'T',
#    '#',
#    '0',
#    '7',
#    'R',
#    'S',
#    '0',
#    '5',
#    'R',
#    'L',
#    '0',
#    '1',
#    'R',
#    't',
#    '0',
#    '1',
#    'R',
#    'T',
#    '0',
#    '1',
#    '@',
#    'V',
#    '1',
#    '3',
#    '$',
#    'M',
#    '1',
#    '1',
#    'M',
#    'S',
#    '1',
#    '1',
#    'M',
#    'T',
#    '0',
#    '1',
#    'R',
#    'V',
#    '0',
#    '1',
#    'R',
#    'D',
#    '1',
#    '2',
#    'B',
#    'W',
#    '0',
#    '6',
#    'B',
#    'J',
#    '-',
#    '6',
#    'B',
#    'B',
#    '0',
#    '6',
#    'R',
#    'T',
#    '0',
#    '6',
#    'R',
#    'H',
#    '0',
#    '6',
#    'O',
#    'I',
#    '0',
#    '1',
#    'R',
#    'U',
#    '1',
#    '7',
#    'R',
#    'V',
#    '1',
#    '7',
#    '@',
#    'A',
#    '0',
#    '1',
#    '@',
#    'G',
#    '0',
#    '1',
#    '@',
#    'D',
#    '0',
#    '1',
#    'R',
#    '#',
#    '1',
#    '5',
#    'R',
#    '#',
#    '1',
#    '5',
#    'S',
#    'J',
#    '-',
#    '8',
#    'S',
#    'K',
#    '-',
#    '8',
#    'R',
#    'D',
#    '0',
#    '4',
#    'H',
#    'L',
#    '1',
#    '1',
#    'H',
#    'I',
#    '1',
#    '1',
#    'S',
#    'K',
#    '1',
#    '1',
#    'R',
#    'A',
#    '0',
#    '1',
#    'R',
#    'M',
#    '1',
#    '6',
#    '#',
#    'M',
#    '0',
#    '5',
#    'R',
#    'N',
#    '1',
#    '5',
#    'T',
#    'A',
#    '0',
#    '2',
#    'T',
#    'L',
#    '0',
#    '2',
#    'T',
#    'A',
#    '0',
#    '2',
#    'T',
#    'L',
#    '0',
#    '2',
#    'R',
#    'P',
#    '0',
#    '1',
#    'R',
#    'F',
#    '-',
#    '7',
#    'R',
#    'M',
#    '0',
#    '7',
#    'R',
#    'S',
#    '0',
#    '5',
#    'R',
#    'C',
#    '0',
#    '5',
#    'R',
#    'E',
#    '0',
#    '1',
#    '1',
#    'E',
#    '0',
#    '1',
#    '1',
#    'F',
#    '0',
#    '1',
#    'R',
#    'B',
#    '1',
#    '1',
#    'R',
#    'H',
#    '0',
#    '1',
#    '.',
#    'G',
#    '1',
#    '7',
#    '.',
#    '#',
#    '0',
#    '7',
#    'R',
#    '#',
#    '0',
#    '6',
#    'R',
#    'S',
#    '1',
#    '7',
#    'R',
#    'U',
#    '0',
#    '1',
#    'R',
#    'J',
#    '1',
#    '1',
#    'H',
#    '#',
#    '1',
#    '4',
#    'R',
#    'B',
#    '0',
#    '7',
#    '$',
#    'A',
#    '-',
#    '8',
#    'R',
#    'B',
#    '0',
#    '1',
#    'N',
#    'Q',
#    '1',
#    '1',
#    'N',
#    'D',
#    '0',
#    '1',
#    '$',
#    'K',
#    '0',
#    '1',
#    '$',
#    'B',
#    '0',
#    '1',
#    'A',
#    'S',
#    '1',
#    '1',
#    'C',
#    '#',
#    '0',
#    '1',
#    'N',
#    '#',
#    '0',
#    '1',
#    'R',
#    'K',
#    '0',
#    '8',
#    'R',
#    'K',
#    '-',
#    '8',
#    'R',
#    'J',
#    '0',
#    '4',
#    'R',
#    'K',
#    '0',
#    '4',
#    'R',
#    'K',
#    '1',
#    '4',
#    'R',
#    'K',
#    '1',
#    '4',
#    'R',
#    'H',
#    '0',
#    '8',
#    'R',
#    'D',
#    '0',
#    '2',
#    'R',
#    'U',
#    '-',
#    '2',
#    'R',
#    'W',
#    '0',
#    '7',
#    'R',
#    'T',
#    '-',
#    '2',
#    'R',
#    'A',
#    '0',
#    '7',
#    'F',
#    'C',
#    '0',
#    '7',
#    'F',
#    'C',
#    '-',
#    '7',
#    'C',
#    'A',
#    '0',
#    '1',
#    'R',
#    'M',
#    '1',
#    '1',
#    'J',
#    'K',
#    '1',
#    '9',
#    'R',
#    'T',
#    '1',
#    '8',
#    'R',
#    'M',
#    '1',
#    '2',
#    'R',
#    'L',
#    '1',
#    '2',
#    '$',
#    'C',
#    '-',
#    '7',
#    'R',
#    'Z',
#    '0',
#    '4',
#    'R',
#    'C',
#    '0',
#    '4',
#    'R',
#    'A',
#    '0',
#    '4',
#    'M',
#    'B',
#    '0',
#    '4',
#    '$',
#    'O',
#    '0',
#    '1',
#    'O',
#    'C',
#    '0',
#    '1',
#    'O',
#    'C',
#    '0',
#    '1',
#    'C',
#    'C',
#    '0',
#    '1',
#    '$',
#    'B',
#    '0',
#    '4',
#    'B',
#    'K',
#    '1',
#    '4',
#    'B',
#    'I',
#    '-',
#    '4',
#    '$',
#    'W',
#    '1',
#    '5',
#    'R',
#    '#',
#    '0',
#    '9',
#    'F',
#    'S',
#    '1',
#    '5',
#    'R',
#    'W',
#    '-',
#    '3',
#    'R',
#    'L',
#    '-',
#    '3',
#    'V',
#    'T',
#    '0',
#    '8',
#    'V',
#    'P',
#    '0',
#    '8',
#    'L',
#    'G',
#    '-',
#    '8',
#    'S',
#    'G',
#    '-',
#    '4',
#    'R',
#    'L',
#    '0',
#    '2',
#    'T',
#    '#',
#    '1',
#    '4',
#    'T',
#    '#',
#    '1',
#    '4',
#    'R',
#    'D',
#    '1',
#    '1',
#    'R',
#    'P',
#    '1',
#    '4',
#    'R',
#    'G',
#    '1',
#    '1',
#    'R',
#    'B',
#    '1',
#    '9',
#    'R',
#    'X',
#    '1',
#    '9',
#    'R',
#    'R',
#    '1',
#    '9',
#    'R',
#    'J',
#    '1',
#    '9',
#    '#',
#    'J',
#    '1',
#    '6',
#    '#',
#    '#',
#    '0',
#    '6',
#    '$',
#    'F',
#    '0',
#    '2',
#    'F',
#    'R',
#    '0',
#    '2',
#    'F',
#    'R',
#    '0',
#    '2',
#    'F',
#    'A',
#    '0',
#    '2',
#    'R',
#    'B',
#    '0',
#    '3',
#    'W',
#    'G',
#    '-',
#    '7',
#    'R',
#    'D',
#    '0',
#    '7',
#    'R',
#    'C',
#    '0',
#    '7',
#    '$',
#    'N',
#    '0',
#    '9',
#    'R',
#    'N',
#    '0',
#    '6',
#    'R',
#    'M',
#    '1',
#    '6',
#    'R',
#    'B',
#    '1',
#    '6',
#    'R',
#    'G',
#    '1',
#    '6',
#    'P',
#    'H',
#    '0',
#    '7',
#    'P',
#    'M',
#    '0',
#    '7',
#    'P',
#    'C',
#    '0',
#    '7',
#    'R',
#    'C',
#    '0',
#    '7',
#    'R',
#    'T',
#    '1',
#    '1',
#    'R',
#    '#',
#    '0',
#    '1',
#    'R',
#    '#',
#    '0',
#    '1',
#    'R',
#    'K',
#    '0',
#    '1',
#    'R',
#    '#',
#    '0',
#    '1',
#    'R',
#    'Z',
#    '0',
#    '1',
#    'R',
#    'C',
#    '1',
#    '6',
#    'G',
#    'W',
#    '1',
#    '4',
#    'G',
#    'G',
#    '0',
#    '4',
#    'E',
#    'J',
#    '0',
#    '1',
#    'R',
#    'C',
#    '0',
#    '5',
#    'R',
#    'I',
#    '0',
#    '7',
#    'R',
#    'F',
#    '0',
#    '7',
#    '$',
#    'G',
#    '0',
#    '8',
#    'G',
#    'A',
#    '0',
#    '8',
#    'G',
#    '#',
#    '0',
#    '8',
#    'R',
#    'G',
#    '0',
#    '7',
#    'R',
#    'S',
#    '-',
#    '1',
#    'R',
#    'C',
#    '-',
#    '3',
#    'R',
#    'D',
#    '0',
#    '3',
#    'R',
#    'N',
#    '1',
#    '5',
#    'R',
#    'G',
#    '-',
#    '4',
#    'R',
#    'G',
#    '-',
#    '4',
#    'M',
#    '#',
#    '0',
#    '2',
#    'A',
#    'L',
#    '1',
#    '1',
#    '$',
#    '#',
#    '1',
#    '7',
#    '#',
#    'J',
#    '1',
#    '7',
#    '#',
#    'J',
#    '1',
#    '7',
#    '#',
#    'N',
#    '0',
#    '7',
#    '$',
#    'K',
#    '0',
#    '7',
#    'K',
#    '#',
#    '0',
#    '7',
#    'R',
#    'T',
#    '0',
#    '2',
#    'R',
#    'A',
#    '1',
#    '2',
#    '5',
#    'D',
#    '0',
#    '7',
#    '5',
#    'P',
#    '0',
#    '7',
#    '$',
#    '#',
#    '0',
#    '7',
#    '#',
#    'B',
#    '0',
#    '7',
#    'R',
#    'N',
#    '0',
#    '1',
#    'R',
#    'D',
#    '-',
#    '1',
#    'R',
#    'K',
#    '1',
#    '1',
#    'R',
#    'A',
#    '0',
#    '7',
#    'R',
#    'B',
#    '0',
#    '2',
#    'R',
#    '5',
#    '0',
#    '1',
#    'R',
#    'E',
#    '0',
#    '1',
#    'T',
#    'N',
#    '0',
#    '1',
#    'R',
#    'D',
#    '1',
#    '1',
#    'R',
#    'L',
#    '1',
#    '4',
#    'R',
#    'S',
#    '0',
#    '7',
#    'R',
#    'Y',
#    '0',
#    '7',
#    'R',
#    'J',
#    '0',
#    '7',
#    'R',
#    'R',
#    '0',
#    '3',
#    'R',
#    'Z',
#    '0',
#    '1',
#    'R',
#    'B',
#    '0',
#    '1',
#    'R',
#    'T',
#    '1',
#    '3',
#    'R',
#    'R',
#    '1',
#    '3',
#    '$',
#    'J',
#    '1',
#    '1',
#    'J',
#    'S',
#    '0',
#    '1',
#    '@',
#    'L',
#    '-',
#    '5',
#    'T',
#    'M',
#    '0',
#    '1',
#    'T',
#    'C',
#    '0',
#    '1',
#    ...]])
